# %%
df["popular"] = df["stars"].apply(lambda x: 1 if x >= 500 else 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df["popular"] = df["stars"].apply(lambda x: 1 if x >= 500 else 0)
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum()

# %%
df.describe(include='all')

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(
    df,
    title="GitHub Repository EDA",
    explorative=True
)
profile.to_file("eda_report.html")

# %%
# Stars Distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df["stars"], bins=50)
plt.title("Stars Distribution")
plt.show()

# %%
## Insight - Distribution plots show that most repositories have low stars, indicating a right-skewed distribution

# %%
# Forks Vs Popularity

# %%
sns.boxplot(x="popular", y="forks", data=df)
plt.title("Forks vs Popularity")
plt.show()

# %%
## Insight - Boxplots for forks vs popularity reveal popular repositories have significantly higher forks

# %%
# Repo age vs Popularity

# %%
sns.boxplot(x="popular", y="repo_age_days", data=df)
plt.show()

# %%
## Insight - Older repositories tend to be more popular.

# %%
# Language Wise Popularity

# %%
df.groupby("language")["popular"].mean().sort_values(ascending=False).head(10).plot(kind="bar")
plt.show()
